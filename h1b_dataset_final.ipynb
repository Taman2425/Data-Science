# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Master H1B Dataset.csv', low_memory=False, encoding="ISO-8859-1")

# %%
df.head(2)
# Out:
#    CASE_SUBMITTED_DAY  CASE_SUBMITTED_MONTH  CASE_SUBMITTED_YEAR  \
# 0                  24                     2                 2016
# 1                   4                     3                 2016
#
#    DECISION_DAY  DECISION_MONTH  DECISION_YEAR VISA_CLASS  \
# 0             1              10           2016        H1B
# 1             1              10           2016        H1B
#
#            EMPLOYER_NAME EMPLOYER_STATE          EMPLOYER_COUNTRY  \
# 0  DISCOVER PRODUCTS INC             IL  UNITED STATES OF AMERICA
# 1       DFS SERVICES LLC             IL  UNITED STATES OF AMERICA
#
#           ...         PW_SOURCE_YEAR              PW_SOURCE_OTHER  \
# 0         ...                 2015.0      OFLC ONLINE DATA CENTER
# 1         ...                 2015.0  WILLIS TOWERS WATSON SURVEY
#
#    WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_TO  WAGE_UNIT_OF_PAY H-1B_DEPENDENT  \
# 0                65811.0             67320.0              Year              N
# ...

# %%
df.describe()
# Out:
#        CASE_SUBMITTED_DAY  CASE_SUBMITTED_MONTH  CASE_SUBMITTED_YEAR  \
# count       528134.000000         528134.000000        528134.000000
# mean            15.246426              4.444859          2016.752854
# std              8.154979              3.201000             0.524568
# min              1.000000              1.000000          2011.000000
# 25%              8.000000              3.000000          2017.000000
# 50%             15.000000              3.000000          2017.000000
# 75%             22.000000              5.000000          2017.000000
# max             31.000000             12.000000          2017.000000
#
#         DECISION_DAY  DECISION_MONTH  DECISION_YEAR     NAICS_CODE  \
# count  528134.000000   528134.000000  528134.000000  528132.000000
# mean       16.565991        4.552377    2016.825876  443548.680673
# std         8.457420        3.201752       0.379217  197875.907540
# min         1.000000        1.000000    2016.000000      31.000000
# ...

# %%
df.groupby(['CASE_STATUS']).size()
# Out:
# CASE_STATUS
# CERTIFIED             468969
# CERTIFIEDWITHDRAWN     36170
# DENIED                  6983
# WITHDRAWN              16012
# dtype: int64

# %%
is_WITHDRAWN =  df['CASE_STATUS']=='WITHDRAWN'
is_DENIED =  df['CASE_STATUS']=='DENIED'
is_CERTIFIEDWITHDRAWN =  df['CASE_STATUS']=='CERTIFIEDWITHDRAWN'
is_CERTIFIED =  df['CASE_STATUS']=='CERTIFIED'

# %%
df_is_WITHDRAWN = df[is_WITHDRAWN]
df_is_DENIED = df[is_DENIED]
df_is_CERTIFIEDWITHDRAWN = df[is_CERTIFIEDWITHDRAWN]
df_is_CERTIFIED = df[is_CERTIFIED]

# %%
print(df_is_CERTIFIED.shape)
# Out:
# (468969, 27)

# %%
np.random.seed(53)
df_is_WITHDRAWN_trim = df_is_WITHDRAWN.sample(6983)
df_is_DENIED_trim = df_is_DENIED.sample(6983)
df_is_CERTIFIEDWITHDRAWN_trim = df_is_CERTIFIEDWITHDRAWN.sample(6983)
df_is_CERTIFIED_trim = df_is_CERTIFIED.sample(6983)

# %%
frames = [df_is_WITHDRAWN_trim, df_is_DENIED_trim, df_is_CERTIFIEDWITHDRAWN_trim, df_is_CERTIFIED_trim]

h1b_df = pd.concat(frames)

# %%
print(h1b_df.shape)
# Out:
# (27932, 27)

# %%
h1b_df.to_csv('h1b_dataset_trimmed.csv', index=False)

# %%
h1b_df2 = h1b_df

# %%
#h1b_df = h1b_df2

# %%
h1b_df.drop(['CASE_SUBMITTED_DAY', 'CASE_SUBMITTED_MONTH','CASE_SUBMITTED_YEAR','DECISION_DAY','DECISION_MONTH','DECISION_YEAR','WORKSITE_POSTAL_CODE', 'EMPLOYER_NAME', 'EMPLOYER_STATE', 'EMPLOYER_COUNTRY', 'PW_SOURCE_YEAR', 'WORKSITE_STATE'], axis=1, inplace=True)

# %%
h1b_df.head(10)
# Out:
#            VISA_CLASS                      SOC_NAME  NAICS_CODE  \
# 283867            H1B                     SCIENTIST      5415.0
# 171362            H1B                    COUNSELORS      4249.0
# 46557   E3 Australian                      ANALYSTS    454111.0
# 226072            H1B                     SCIENTIST    611310.0
# 123776            H1B                   ACCOUNTANTS    541510.0
# 8897              H1B                      ANALYSTS    541490.0
# 252329            H1B                     SCIENTIST    541712.0
# 226031            H1B                     EDUCATION      5415.0
# 226080            H1B                     SCIENTIST    541519.0
# 242937            H1B  REPORTERS AND CORRESPONDENTS     54121.0
#
#         TOTAL_WORKERS FULL_TIME_POSITION  PREVAILING_WAGE PW_SOURCE  \
# 283867              1                  Y        114962.00       OES
# 171362              1                  N         73476.48       OES
# ...

# %%
h1b_df['WAGE_RATE_OF_PAY_FROM'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Hour', h1b_df['WAGE_RATE_OF_PAY_FROM']*2112, h1b_df['WAGE_RATE_OF_PAY_FROM'])
h1b_df['PREVAILING_WAGE'] = np.where(h1b_df['PW_UNIT_OF_PAY']=='Hour', h1b_df['PREVAILING_WAGE']*2112, h1b_df['PREVAILING_WAGE'])
h1b_df['WAGE_RATE_OF_PAY_TO'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Hour', h1b_df['WAGE_RATE_OF_PAY_TO']*2112, h1b_df['WAGE_RATE_OF_PAY_TO'])

# %%
h1b_df['WAGE_RATE_OF_PAY_FROM'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Bi-Weekly', h1b_df['WAGE_RATE_OF_PAY_FROM']*104, h1b_df['WAGE_RATE_OF_PAY_FROM'])
h1b_df['PREVAILING_WAGE'] = np.where(h1b_df['PW_UNIT_OF_PAY']=='Bi-Weekly', h1b_df['PREVAILING_WAGE']*104, h1b_df['PREVAILING_WAGE'])
h1b_df['WAGE_RATE_OF_PAY_TO'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Bi-Weekly', h1b_df['WAGE_RATE_OF_PAY_TO']*104, h1b_df['WAGE_RATE_OF_PAY_TO'])

# %%
h1b_df['WAGE_RATE_OF_PAY_FROM'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Month', h1b_df['WAGE_RATE_OF_PAY_FROM']*12, h1b_df['WAGE_RATE_OF_PAY_FROM'])
h1b_df['PREVAILING_WAGE'] = np.where(h1b_df['PW_UNIT_OF_PAY']=='Month', h1b_df['PREVAILING_WAGE']*12, h1b_df['PREVAILING_WAGE'])
h1b_df['WAGE_RATE_OF_PAY_TO'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Month', h1b_df['WAGE_RATE_OF_PAY_TO']*12, h1b_df['WAGE_RATE_OF_PAY_TO'])

# %%
h1b_df['WAGE_RATE_OF_PAY_FROM'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Week', h1b_df['WAGE_RATE_OF_PAY_FROM']*52, h1b_df['WAGE_RATE_OF_PAY_FROM'])
h1b_df['PREVAILING_WAGE'] = np.where(h1b_df['PW_UNIT_OF_PAY']=='Week', h1b_df['PREVAILING_WAGE']*52, h1b_df['PREVAILING_WAGE'])
h1b_df['WAGE_RATE_OF_PAY_TO'] = np.where(h1b_df['WAGE_UNIT_OF_PAY']=='Week', h1b_df['WAGE_RATE_OF_PAY_TO']*52, h1b_df['WAGE_RATE_OF_PAY_TO'])

# %%
df.groupby(['WAGE_UNIT_OF_PAY']).size()
# Out:
# WAGE_UNIT_OF_PAY
# Bi-Weekly       104
# Hour          32793
# Month           397
# Week            172
# Year         494664
# dtype: int64

# %%
h1b_df.drop(['WAGE_UNIT_OF_PAY','PW_UNIT_OF_PAY'], axis=1, inplace=True)

# %%
h1b_df.shape
# Out:
# (27932, 13)

# %%
h1b_df.head(2)
# Out:
#        VISA_CLASS    SOC_NAME  NAICS_CODE  TOTAL_WORKERS FULL_TIME_POSITION  \
# 283867        H1B   SCIENTIST      5415.0              1                  Y
# 171362        H1B  COUNSELORS      4249.0              1                  N
#
#         PREVAILING_WAGE PW_UNIT_OF_PAY PW_SOURCE          PW_SOURCE_OTHER  \
# 283867        114962.00           Year       OES  OFLC ONLINE DATA CENTER
# 171362            34.79           Hour       OES  OFLC ONLINE DATA CENTER
#
#         WAGE_RATE_OF_PAY_FROM  WAGE_RATE_OF_PAY_TO WAGE_UNIT_OF_PAY  \
# 283867              115000.00                  0.0             Year
# 171362                  34.79                  0.0             Hour
#
#        H-1B_DEPENDENT WILLFUL_VIOLATOR CASE_STATUS
# 283867              Y                N   WITHDRAWN
# 171362              N                N   WITHDRAWN

# %%
h1b_df_encoded = pd.get_dummies(h1b_df[['VISA_CLASS', 'SOC_NAME', 'FULL_TIME_POSITION',  'PW_SOURCE', 'PW_SOURCE_OTHER','H-1B_DEPENDENT','WILLFUL_VIOLATOR']],drop_first=True)

# %%
h1b_df_encoded.shape
# Out:
# (27932, 223)

# %%
h1b_df_encoded.head(2)
# Out:
#         VISA_CLASS_H1B  VISA_CLASS_H1B1 Chile  VISA_CLASS_H1B1 Singapore  \
# 283867               1                      0                          0
# 171362               1                      0                          0
#
#         SOC_NAME_ACTUARIES  SOC_NAME_AGRICULTURE  SOC_NAME_ANALYSTS  \
# 283867                   0                     0                  0
# 171362                   0                     0                  0
#
#         SOC_NAME_ANIMAL HUSBANDARY  SOC_NAME_ARCHITECTURE  \
# 283867                           0                      0
# 171362                           0                      0
#
#         SOC_NAME_BUSINESS OPERATIONS SPECIALIST  SOC_NAME_CHIEF EXECUTIVES  \
# 283867                                        0                          0
# 171362                                        0                          0
#
#                ...          \
# 283867         ...
# 171362         ...
#
# ...

# %%
result = pd.concat([ h1b_df_encoded, h1b_df[['NAICS_CODE','TOTAL_WORKERS', 'PREVAILING_WAGE','WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'CASE_STATUS']]], axis=1)

# %%
result.shape
# Out:
# (27932, 229)

# %%
result.head(2)
# Out:
#         VISA_CLASS_H1B  VISA_CLASS_H1B1 Chile  VISA_CLASS_H1B1 Singapore  \
# 283867               1                      0                          0
# 171362               1                      0                          0
#
#         SOC_NAME_ACTUARIES  SOC_NAME_AGRICULTURE  SOC_NAME_ANALYSTS  \
# 283867                   0                     0                  0
# 171362                   0                     0                  0
#
#         SOC_NAME_ANIMAL HUSBANDARY  SOC_NAME_ARCHITECTURE  \
# 283867                           0                      0
# 171362                           0                      0
#
#         SOC_NAME_BUSINESS OPERATIONS SPECIALIST  SOC_NAME_CHIEF EXECUTIVES  \
# 283867                                        0                          0
# 171362                                        0                          0
#
#            ...       PW_SOURCE_OTHER_WWFCLDATACENTER  \
# 283867     ...                                     0
# ...

# %%
df.groupby(['WAGE_RATE_OF_PAY_TO']).size()
# Out:
# WAGE_RATE_OF_PAY_TO
# 0.00          413260
# 7.50               7
# 8.00               4
# 8.50               1
# 8.75               1
# 9.00               2
# 9.21               1
# 9.24               3
# 9.50               3
# 10.00              6
# 10.20              1
# 10.42              1
# 10.50              2
# 10.62              1
# 11.00              5
# 11.17              1
# 11.25              2
# 11.26              1
# 11.54              1
# 11.91              1
# 12.00             11
# 12.30              1
# 12.41              2
# 12.50              2
# 12.84              2
# 13.00              3
# 13.50              3
# 13.75              1
# 13.86              1
# 14.00             12
#                ...
# 630000.00          2
# 635000.00          1
# 650000.00          9
# 675000.00          3
# 685000.00          1
# 695000.00          1
# 700000.00          8
# 725000.00          1
# 727999.00          1
# 750000.00          2
# 765000.00          2
# ...

# %%
null_columns=result.columns[result.isnull().any()]

# %%
result[null_columns].isnull().sum()
# Out:
# NAICS_CODE    2
# dtype: int64

# %%
result = result[np.isfinite(result['NAICS_CODE'])]

# %%
result.fillna(0)
# Out:
#         VISA_CLASS_H1B  VISA_CLASS_H1B1 Chile  VISA_CLASS_H1B1 Singapore  \
# 283867               1                      0                          0
# 171362               1                      0                          0
# 46557                0                      0                          0
# 226072               1                      0                          0
# 123776               1                      0                          0
# 8897                 1                      0                          0
# 252329               1                      0                          0
# 226031               1                      0                          0
# 226080               1                      0                          0
# 242937               1                      0                          0
# 344360               1                      0                          0
# 321014               1                      0                          0
# ...

# %%
from sklearn.model_selection import train_test_split

# create design matrix X and target vector y
X = np.array(result.ix[:, 0:228]) # end index is exclusive
y = np.array(result['CASE_STATUS']) # another way of indexing a pandas df

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (18713, 228)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# instantiate learning model (k = 3)
knn = KNeighborsClassifier(n_neighbors=3)

# fitting the model
knn.fit(X_train, y_train)

# predict the response
pred = knn.predict(X_test)

# evaluate accuracy
print (accuracy_score(y_test, pred))
# Out:
# 0.38439839427145495

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.62

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
print('Accuracy of LDA classifier on training set: {:.2f}'
     .format(lda.score(X_train, y_train)))
print('Accuracy of LDA classifier on test set: {:.2f}'
     .format(lda.score(X_test, y_test)))
# Out:
# Accuracy of LDA classifier on training set: 0.67
# Accuracy of LDA classifier on test set: 0.67
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(svm.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.2f}'
     .format(svm.score(X_test, y_test)))

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
print('Accuracy of GNB classifier on training set: {:.2f}'
     .format(gnb.score(X_train, y_train)))
print('Accuracy of GNB classifier on test set: {:.2f}'
     .format(gnb.score(X_test, y_test)))
# Out:
# Accuracy of GNB classifier on training set: 0.32
# Accuracy of GNB classifier on test set: 0.32

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.59
# Accuracy of K-NN classifier on test set: 0.41

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.29
# Accuracy of Logistic regression classifier on test set: 0.29
